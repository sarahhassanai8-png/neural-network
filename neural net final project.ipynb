# %%
import torch
import torch.nn as nn
import torch.optim as optim
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

#data
data = pd.read_csv("Heart_disease - Heart_disease.csv")
X = data.drop("target", axis=1).values
y = data["target"].values

#split
X_temp, X_test, y_temp, y_test = train_test_split(X, y, test_size=0.2)
X_train, X_val, y_train, y_val = train_test_split(X_temp, y_temp, test_size=0.25)

#Scaling
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)

#tensors
X_train = torch.FloatTensor(X_train)
y_train = torch.FloatTensor(y_train).view(-1, 1)
X_val = torch.FloatTensor(X_val)
y_val = torch.FloatTensor(y_val).view(-1, 1)
X_test = torch.FloatTensor(X_test)
y_test = torch.FloatTensor(y_test).view(-1, 1)

#models&func
def build_model(activation_fn):
    model = nn.Sequential(
        nn.Linear(X_train.shape[1], 32),
        nn.BatchNorm1d(32),
        activation_fn(),
        nn.Dropout(0.3),

        nn.Linear(32, 16),
        nn.BatchNorm1d(16),
        activation_fn(),
        nn.Dropout(0.3),

        nn.Linear(16, 1),
        nn.Sigmoid()
    )
    return model

#training
def train_model(model, lr=0.001, epochs=100):
    optimizer = optim.Adam(model.parameters(), lr=lr)
    criterion = nn.BCELoss()

    train_losses = []
    val_losses = []

    for epoch in range(epochs):
    ##
        model.train()
        outputs = model(X_train)
        loss = criterion(outputs, y_train)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        #validation
        model.eval()
        with torch.no_grad():
            val_outputs = model(X_val)
            val_loss = criterion(val_outputs, y_val)

        train_losses.append(loss.item())
        val_losses.append(val_loss.item())

        print(f"Epoch {epoch+1} | Train: {loss.item():.4f} | Val: {val_loss.item():.4f}")

    return train_losses, val_losses


#Evaluation Function
def evaluate(model):
    model.eval()
    with torch.no_grad():
        preds = model(X_test)
        preds = (preds > 0.5).float()
        acc = (preds == y_test).sum() / y_test.shape[0]

    return acc.item()


#ReLU

print("\nReLU")

model_relu = build_model(nn.ReLU)
train_loss_relu, val_loss_relu = train_model(model_relu)

acc_relu = evaluate(model_relu)
print("Test Accuracy (ReLU):", acc_relu)


#Tanh
print("\nTanh")

model_tanh = build_model(nn.Tanh)
train_loss_tanh, val_loss_tanh = train_model(model_tanh)

acc_tanh = evaluate(model_tanh)
print("Test Accuracy (Tanh):", acc_tanh)

#charts
plt.plot(train_loss_relu, label="Train ReLU")
plt.plot(val_loss_relu, label="Val ReLU")

plt.plot(train_loss_tanh, label="Train Tanh")
plt.plot(val_loss_tanh, label="Val Tanh")

plt.legend()
plt.title("Training vs Validation Loss")
plt.show()

#accuracy
print("\nFinal Comparison")
print(f"ReLU Accuracy: {acc_relu:.4f}")
print(f"Tanh Accuracy: {acc_tanh:.4f}")
# Out:
# ReLU
# Epoch 1 | Train: 0.6146 | Val: 0.6242
# Epoch 2 | Train: 0.6051 | Val: 0.6231
# Epoch 3 | Train: 0.6029 | Val: 0.6217
# Epoch 4 | Train: 0.6001 | Val: 0.6200
# Epoch 5 | Train: 0.5944 | Val: 0.6179
# Epoch 6 | Train: 0.5844 | Val: 0.6156
# Epoch 7 | Train: 0.5831 | Val: 0.6129
# Epoch 8 | Train: 0.5775 | Val: 0.6099
# Epoch 9 | Train: 0.5742 | Val: 0.6065
# Epoch 10 | Train: 0.5686 | Val: 0.6030
# Epoch 11 | Train: 0.5643 | Val: 0.5992
# Epoch 12 | Train: 0.5572 | Val: 0.5953
# Epoch 13 | Train: 0.5560 | Val: 0.5912
# Epoch 14 | Train: 0.5511 | Val: 0.5869
# Epoch 15 | Train: 0.5457 | Val: 0.5825
# Epoch 16 | Train: 0.5485 | Val: 0.5781
# Epoch 17 | Train: 0.5385 | Val: 0.5735
# Epoch 18 | Train: 0.5344 | Val: 0.5689
# Epoch 19 | Train: 0.5358 | Val: 0.5643
# Epoch 20 | Train: 0.5259 | Val: 0.5599
# Epoch 21 | Train: 0.5216 | Val: 0.5555
# Epoch 22 | Train: 0.5247 | Val: 0.5510
# Epoch 23 | Train: 0.5159 | Val: 0.5466
# Epoch 24 | Train: 0.5113 | Val: 0.5421
# Epoch 25 | Train: 0.5086 | Val: 0.5377
# Epoch 26 | Train: 0.5040 | Val: 0.5336
# Epoch 27 | Train: 0.5062 | Val: 0.5294
# Epoch 28 | Train: 0.5036 | Val: 0.5254
# Epoch 29 | Train: 0.4958 | Val: 0.5212
# Epoch 30 | Train: 0.4946 | Val: 0.5174
# Epoch 31 | Train: 0.4929 | Val: 0.5139
# Epoch 32 | Train: 0.4864 | Val: 0.5104
# Epoch 33 | Train: 0.4851 | Val: 0.5068
# Epoch 34 | Train: 0.4827 | Val: 0.5033
# Epoch 35 | Train: 0.4740 | Val: 0.5000
# Epoch 36 | Train: 0.4709 | Val: 0.4968
# Epoch 37 | Train: 0.4692 | Val: 0.4935
# Epoch 38 | Train: 0.4655 | Val: 0.4902
# Epoch 39 | Train: 0.4666 | Val: 0.4872
# Epoch 40 | Train: 0.4640 | Val: 0.4841
# Epoch 41 | Train: 0.4594 | Val: 0.4810
# Epoch 42 | Train: 0.4501 | Val: 0.4779
# Epoch 43 | Train: 0.4501 | Val: 0.4751
# Epoch 44 | Train: 0.4496 | Val: 0.4722
# Epoch 45 | Train: 0.4461 | Val: 0.4693
# Epoch 46 | Train: 0.4388 | Val: 0.4663
# Epoch 47 | Train: 0.4401 | Val: 0.4636
# Epoch 48 | Train: 0.4394 | Val: 0.4609
# Epoch 49 | Train: 0.4329 | Val: 0.4583
# Epoch 50 | Train: 0.4293 | Val: 0.4558
# Epoch 51 | Train: 0.4286 | Val: 0.4533
# Epoch 52 | Train: 0.4266 | Val: 0.4505
# Epoch 53 | Train: 0.4239 | Val: 0.4480
# Epoch 54 | Train: 0.4199 | Val: 0.4454
# Epoch 55 | Train: 0.4154 | Val: 0.4429
# Epoch 56 | Train: 0.4147 | Val: 0.4402
# Epoch 57 | Train: 0.4117 | Val: 0.4375
# Epoch 58 | Train: 0.4075 | Val: 0.4350
# Epoch 59 | Train: 0.4088 | Val: 0.4326
# Epoch 60 | Train: 0.4033 | Val: 0.4301
# Epoch 61 | Train: 0.4001 | Val: 0.4278
# Epoch 62 | Train: 0.4013 | Val: 0.4252
# Epoch 63 | Train: 0.3988 | Val: 0.4227
# Epoch 64 | Train: 0.3966 | Val: 0.4203
# Epoch 65 | Train: 0.3921 | Val: 0.4178
# Epoch 66 | Train: 0.3929 | Val: 0.4154
# Epoch 67 | Train: 0.3875 | Val: 0.4128
# Epoch 68 | Train: 0.3886 | Val: 0.4103
# Epoch 69 | Train: 0.3835 | Val: 0.4078
# Epoch 70 | Train: 0.3827 | Val: 0.4052
# Epoch 71 | Train: 0.3795 | Val: 0.4028
# Epoch 72 | Train: 0.3767 | Val: 0.4001
# Epoch 73 | Train: 0.3720 | Val: 0.3975
# Epoch 74 | Train: 0.3734 | Val: 0.3946
# Epoch 75 | Train: 0.3676 | Val: 0.3917
# Epoch 76 | Train: 0.3684 | Val: 0.3892
# Epoch 77 | Train: 0.3680 | Val: 0.3868
# Epoch 78 | Train: 0.3671 | Val: 0.3841
# Epoch 79 | Train: 0.3660 | Val: 0.3815
# Epoch 80 | Train: 0.3611 | Val: 0.3789
# Epoch 81 | Train: 0.3580 | Val: 0.3763
# Epoch 82 | Train: 0.3565 | Val: 0.3736
# Epoch 83 | Train: 0.3524 | Val: 0.3710
# Epoch 84 | Train: 0.3496 | Val: 0.3685
# Epoch 85 | Train: 0.3503 | Val: 0.3661
# Epoch 86 | Train: 0.3454 | Val: 0.3638
# Epoch 87 | Train: 0.3473 | Val: 0.3617
# Epoch 88 | Train: 0.3429 | Val: 0.3594
# Epoch 89 | Train: 0.3446 | Val: 0.3573
# Epoch 90 | Train: 0.3429 | Val: 0.3552
# Epoch 91 | Train: 0.3383 | Val: 0.3532
# Epoch 92 | Train: 0.3362 | Val: 0.3511
# Epoch 93 | Train: 0.3348 | Val: 0.3491
# Epoch 94 | Train: 0.3315 | Val: 0.3472
# Epoch 95 | Train: 0.3289 | Val: 0.3450
# Epoch 96 | Train: 0.3276 | Val: 0.3431
# Epoch 97 | Train: 0.3358 | Val: 0.3410
# Epoch 98 | Train: 0.3263 | Val: 0.3390
# Epoch 99 | Train: 0.3287 | Val: 0.3371
# Epoch 100 | Train: 0.3209 | Val: 0.3351
# Test Accuracy (ReLU): 0.9329897165298462
#
# Tanh
# Epoch 1 | Train: 0.6521 | Val: 0.6669
# Epoch 2 | Train: 0.6487 | Val: 0.6623
# Epoch 3 | Train: 0.6467 | Val: 0.6578
# Epoch 4 | Train: 0.6419 | Val: 0.6532
# Epoch 5 | Train: 0.6410 | Val: 0.6487
# Epoch 6 | Train: 0.6371 | Val: 0.6443
# Epoch 7 | Train: 0.6299 | Val: 0.6399
# Epoch 8 | Train: 0.6270 | Val: 0.6354
# Epoch 9 | Train: 0.6266 | Val: 0.6315
# Epoch 10 | Train: 0.6234 | Val: 0.6275
# Epoch 11 | Train: 0.6230 | Val: 0.6235
# Epoch 12 | Train: 0.6192 | Val: 0.6197
# Epoch 13 | Train: 0.6161 | Val: 0.6160
# Epoch 14 | Train: 0.6145 | Val: 0.6124
# Epoch 15 | Train: 0.6059 | Val: 0.6090
# Epoch 16 | Train: 0.6100 | Val: 0.6058
# Epoch 17 | Train: 0.6058 | Val: 0.6030
# Epoch 18 | Train: 0.6021 | Val: 0.6003
# Epoch 19 | Train: 0.6069 | Val: 0.5974
# Epoch 20 | Train: 0.6002 | Val: 0.5948
# Epoch 21 | Train: 0.5963 | Val: 0.5921
# Epoch 22 | Train: 0.5965 | Val: 0.5898
# Epoch 23 | Train: 0.5981 | Val: 0.5877
# Epoch 24 | Train: 0.5971 | Val: 0.5856
# Epoch 25 | Train: 0.5932 | Val: 0.5833
# Epoch 26 | Train: 0.5862 | Val: 0.5814
# Epoch 27 | Train: 0.5886 | Val: 0.5792
# Epoch 28 | Train: 0.5849 | Val: 0.5771
# Epoch 29 | Train: 0.5836 | Val: 0.5749
# Epoch 30 | Train: 0.5894 | Val: 0.5730
# Epoch 31 | Train: 0.5770 | Val: 0.5713
# Epoch 32 | Train: 0.5815 | Val: 0.5696
# Epoch 33 | Train: 0.5818 | Val: 0.5676
# Epoch 34 | Train: 0.5748 | Val: 0.5657
# Epoch 35 | Train: 0.5757 | Val: 0.5639
# Epoch 36 | Train: 0.5752 | Val: 0.5619
# Epoch 37 | Train: 0.5676 | Val: 0.5601
# Epoch 38 | Train: 0.5677 | Val: 0.5582
# Epoch 39 | Train: 0.5712 | Val: 0.5561
# Epoch 40 | Train: 0.5678 | Val: 0.5543
# Epoch 41 | Train: 0.5678 | Val: 0.5524
# Epoch 42 | Train: 0.5643 | Val: 0.5505
# Epoch 43 | Train: 0.5632 | Val: 0.5486
# Epoch 44 | Train: 0.5590 | Val: 0.5464
# Epoch 45 | Train: 0.5589 | Val: 0.5445
# Epoch 46 | Train: 0.5570 | Val: 0.5427
# Epoch 47 | Train: 0.5519 | Val: 0.5410
# Epoch 48 | Train: 0.5510 | Val: 0.5388
# Epoch 49 | Train: 0.5536 | Val: 0.5369
# Epoch 50 | Train: 0.5510 | Val: 0.5348
# Epoch 51 | Train: 0.5516 | Val: 0.5328
# Epoch 52 | Train: 0.5453 | Val: 0.5308
# Epoch 53 | Train: 0.5454 | Val: 0.5287
# Epoch 54 | Train: 0.5473 | Val: 0.5266
# Epoch 55 | Train: 0.5444 | Val: 0.5246
# Epoch 56 | Train: 0.5431 | Val: 0.5227
# Epoch 57 | Train: 0.5446 | Val: 0.5206
# Epoch 58 | Train: 0.5360 | Val: 0.5183
# Epoch 59 | Train: 0.5354 | Val: 0.5161
# Epoch 60 | Train: 0.5367 | Val: 0.5141
# Epoch 61 | Train: 0.5323 | Val: 0.5119
# Epoch 62 | Train: 0.5283 | Val: 0.5096
# Epoch 63 | Train: 0.5282 | Val: 0.5073
# Epoch 64 | Train: 0.5257 | Val: 0.5049
# Epoch 65 | Train: 0.5203 | Val: 0.5027
# Epoch 66 | Train: 0.5218 | Val: 0.5002
# Epoch 67 | Train: 0.5192 | Val: 0.4977
# Epoch 68 | Train: 0.5169 | Val: 0.4953
# Epoch 69 | Train: 0.5165 | Val: 0.4927
# Epoch 70 | Train: 0.5130 | Val: 0.4902
# Epoch 71 | Train: 0.5147 | Val: 0.4878
# Epoch 72 | Train: 0.5046 | Val: 0.4853
# Epoch 73 | Train: 0.5083 | Val: 0.4829
# Epoch 74 | Train: 0.5084 | Val: 0.4805
# Epoch 75 | Train: 0.5043 | Val: 0.4783
# Epoch 76 | Train: 0.4991 | Val: 0.4758
# Epoch 77 | Train: 0.5013 | Val: 0.4735
# Epoch 78 | Train: 0.4981 | Val: 0.4712
# Epoch 79 | Train: 0.4969 | Val: 0.4689
# Epoch 80 | Train: 0.4874 | Val: 0.4668
# Epoch 81 | Train: 0.4924 | Val: 0.4644
# Epoch 82 | Train: 0.4890 | Val: 0.4622
# Epoch 83 | Train: 0.4870 | Val: 0.4600
# Epoch 84 | Train: 0.4881 | Val: 0.4574
# Epoch 85 | Train: 0.4816 | Val: 0.4550
# Epoch 86 | Train: 0.4813 | Val: 0.4525
# Epoch 87 | Train: 0.4790 | Val: 0.4501
# Epoch 88 | Train: 0.4755 | Val: 0.4476
# Epoch 89 | Train: 0.4733 | Val: 0.4454
# Epoch 90 | Train: 0.4745 | Val: 0.4430
# Epoch 91 | Train: 0.4700 | Val: 0.4407
# Epoch 92 | Train: 0.4670 | Val: 0.4384
# Epoch 93 | Train: 0.4652 | Val: 0.4362
# Epoch 94 | Train: 0.4674 | Val: 0.4339
# Epoch 95 | Train: 0.4627 | Val: 0.4319
# Epoch 96 | Train: 0.4603 | Val: 0.4296
# Epoch 97 | Train: 0.4574 | Val: 0.4277
# Epoch 98 | Train: 0.4514 | Val: 0.4256
# Epoch 99 | Train: 0.4532 | Val: 0.4234
# Epoch 100 | Train: 0.4510 | Val: 0.4214
# Test Accuracy (Tanh): 0.8154639005661011
# Final Comparison
# ReLU Accuracy: 0.9330
# Tanh Accuracy: 0.8155
